# %%
import pandas as pd
from email_validator import validate_email, EmailNotValidError

# %%
def check_for_valid(email):
    try:
        emailinfo = validate_email(email, check_deliverability=True)
        email = emailinfo.normalized
        return 'valid and normalized'
    except EmailNotValidError as e:
        return f'is invalid: {str(e)}'  # Возвращаем сообщение об ошибке для отладки
    except Exception as e:
        return f'Error: {str(e)}' # Ловим другие ошибки



df = pd.read_excel('Продажи по контрагентам обработаный.xlsx', sheet_name='Sheet1')
df['check_for_valied_email'] = df['Email'].apply(check_for_valid)
# Out:
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# File c:\Python313\Lib\site-packages\dns\query.py:651, in _udp_recv(sock, max_size, expiration)
#     650 try:
# --> 651     return sock.recvfrom(max_size)
#     652 except BlockingIOError:
#
# BlockingIOError: [WinError 10035] Операция на незаблокированном сокете не может быть завершена немедленно
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 14
#       9         return f'Error: {str(e)}' # Ловим другие ошибки
#      13 df = pd.read_excel('Продажи по контрагентам обработаный.xlsx', sheet_name='Sheet1')
# ---> 14 df['check_for_valied_email'] = df['Email'].apply(check_for_valid)
#
# File c:\Python313\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Python313\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Python313\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Python313\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[15], line 3, in check_for_valid(email)
#       1 def check_for_valid(email):
#       2     try:
# ----> 3         emailinfo = validate_email(email, check_deliverability=True)
#       4         email = emailinfo.normalized
#       5         return 'valid and normalized'
#
# File c:\Python313\Lib\site-packages\email_validator\validate_email.py:172, in validate_email(email, allow_smtputf8, allow_empty_local, allow_quoted_local, allow_domain_literal, allow_display_name, check_deliverability, test_environment, globally_deliverable, timeout, dns_resolver)
#     170 # Lazy load `deliverability` as it is slow to import (due to dns.resolver)
#     171 from .deliverability import validate_email_deliverability
# --> 172 deliverability_info = validate_email_deliverability(
#     173     ret.ascii_domain, ret.domain, timeout, dns_resolver
#     174 )
#     175 mx = deliverability_info.get("mx")
#     176 if mx is not None:
#
# File c:\Python313\Lib\site-packages\email_validator\deliverability.py:51, in validate_email_deliverability(domain, domain_i18n, timeout, dns_resolver)
#      48 try:
#      49     try:
#      50         # Try resolving for MX records (RFC 5321 Section 5).
# ---> 51         response = dns_resolver.resolve(domain, "MX")
#      53         # For reporting, put them in priority order and remove the trailing dot in the qnames.
#      54         mtas = sorted([(r.preference, str(r.exchange).rstrip('.')) for r in response])
#
# File c:\Python313\Lib\site-packages\dns\resolver.py:1322, in Resolver.resolve(self, qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1320 timeout = self._compute_timeout(start, lifetime, resolution.errors)
#    1321 try:
# -> 1322     response = nameserver.query(
#    1323         request,
#    1324         timeout=timeout,
#    1325         source=source,
#    1326         source_port=source_port,
#    1327         max_size=tcp,
#    1328     )
#    1329 except Exception as ex:
#    1330     (_, done) = resolution.query_result(None, ex)
#
# File c:\Python313\Lib\site-packages\dns\nameserver.py:108, in Do53Nameserver.query(self, request, timeout, source, source_port, max_size, one_rr_per_rrset, ignore_trailing)
#      97     response = dns.query.tcp(
#      98         request,
#      99         self.address,
#    (...)    105         ignore_trailing=ignore_trailing,
#     106     )
#     107 else:
# --> 108     response = dns.query.udp(
#     109         request,
#     110         self.address,
#     111         timeout=timeout,
#     112         port=self.port,
#     113         source=source,
#     114         source_port=source_port,
#     115         raise_on_truncation=True,
#     116         one_rr_per_rrset=one_rr_per_rrset,
#     117         ignore_trailing=ignore_trailing,
#     118         ignore_errors=True,
#     119         ignore_unexpected=True,
#     120     )
#     121 return response
#
# File c:\Python313\Lib\site-packages\dns\query.py:873, in udp(q, where, timeout, port, source, source_port, ignore_unexpected, one_rr_per_rrset, ignore_trailing, raise_on_truncation, sock, ignore_errors)
#     871 with cm as s:
#     872     send_udp(s, wire, destination, expiration)
# --> 873     (r, received_time) = receive_udp(
#     874         s,
#     875         destination,
#     876         expiration,
#     877         ignore_unexpected,
#     878         one_rr_per_rrset,
#     879         q.keyring,
#     880         q.mac,
#     881         ignore_trailing,
#     882         raise_on_truncation,
#     883         ignore_errors,
#     884         q,
#     885     )
#     886     r.time = received_time - begin_time
#     887     # We don't need to check q.is_response() if we are in ignore_errors mode
#     888     # as receive_udp() will have checked it.
#
# File c:\Python313\Lib\site-packages\dns\query.py:764, in receive_udp(sock, destination, expiration, ignore_unexpected, one_rr_per_rrset, keyring, request_mac, ignore_trailing, raise_on_truncation, ignore_errors, query)
#     762 wire = b""
#     763 while True:
# --> 764     (wire, from_address) = _udp_recv(sock, 65535, expiration)
#     765     if not _matches_destination(
#     766         sock.family, from_address, destination, ignore_unexpected
#     767     ):
#     768         continue
#
# File c:\Python313\Lib\site-packages\dns\query.py:653, in _udp_recv(sock, max_size, expiration)
#     651     return sock.recvfrom(max_size)
#     652 except BlockingIOError:
# --> 653     _wait_for_readable(sock, expiration)
#
# File c:\Python313\Lib\site-packages\dns\query.py:241, in _wait_for_readable(s, expiration)
#     240 def _wait_for_readable(s, expiration):
# --> 241     _wait_for(s, True, False, True, expiration)
#
# File c:\Python313\Lib\site-packages\dns\query.py:236, in _wait_for(fd, readable, writable, _, expiration)
#     234     if timeout <= 0.0:
#     235         raise dns.exception.Timeout
# --> 236 if not sel.select(timeout):
#     237     raise dns.exception.Timeout
#
# File c:\Python313\Lib\selectors.py:314, in SelectSelector.select(self, timeout)
#     312 ready = []
#     313 try:
# --> 314     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     315 except InterruptedError:
#     316     return ready
#
# File c:\Python313\Lib\selectors.py:305, in SelectSelector._select(self, r, w, _, timeout)
#     304 def _select(self, r, w, _, timeout=None):
# --> 305     r, w, x = select.select(r, w, w, timeout)
#     306     return r, w + x, []
#
# KeyboardInterrupt:

# %%
df
# Out:
#       Unnamed: 0                 Контрагент           ИНН  \
# 0              0                 ГАРФИН ООО    7743362814
# 1              1                 НОНТОН ООО    7802696219
# 2              3                ТОПФЛОР ООО    9717095669
# 3              4                ТОПФЛОР ООО    9717095669
# 4              5  Мазурин Евгений Борисович  482600785910
# ...          ...                        ...           ...
# 2655        2788        КИРОВСКИЙ ССК АО СЗ    4345146992
# 2656        2789        КИРОВСКИЙ ССК АО СЗ    4345146992
# 2657        2790                    ЭРА ООО    7801708060
# 2658        2791              РБС ГРУПП ООО    7720794984
# 2659        2792              РБС ГРУПП ООО    7720794984
#
#                          Email
# 0              mto@garfin-m.ru
# 1               info@nonton.ru
# 2     gorushkonastya@yandex.ru
# 3          info@topfloormsk.ru
# 4           lrs.maz@lrsk.48.ru
# ...                        ...
# 2655  iraida.devyatykh@mail.ru
# 2656     kolchanova_av@mail.ru
# 2657  vladimir_mihalko@mail.ru
# 2658              info@rbsg.ru
# 2659            order@ateri.ru
#
# [2660 rows x 4 columns]
